# %%
#Name: Jyotiprakash Panda , Roll no: 22052464
import numpy as np

A = np.array([[3, 1], [1, 3]])
U, S, Vt = np.linalg.svd(A)
A_reconstructed = np.dot(U, np.dot(np.diag(S), Vt))
print(A_reconstructed)
# Out:
# [[3. 1.]
#  [1. 3.]]

# %%
def cube(x):
    return x ** 3

cube_ufunc = np.frompyfunc(cube, 1, 1)
arr = np.array([1, 2, 3, 4])
result = cube_ufunc(arr)
print(result)
# Out:
# [1 8 27 64]

# %%
import numpy as np

def strassen(A, B):
    n = A.shape[0]
    
    if n == 1:
        return A * B
    else:
        mid = n // 2
        A11 = A[:mid, :mid]
        A12 = A[:mid, mid:]
        A21 = A[mid:, :mid]
        A22 = A[mid:, mid:]
        B11 = B[:mid, :mid]
        B12 = B[:mid, mid:]
        B21 = B[mid:, :mid]
        B22 = B[mid:, mid:]

        M1 = strassen(A11 + A22, B11 + B22)
        M2 = strassen(A21 + A22, B11)
        M3 = strassen(A11, B12 - B22)
        M4 = strassen(A22, B21 - B11)
        M5 = strassen(A11 + A12, B22)
        M6 = strassen(A21 - A11, B11 + B12)
        M7 = strassen(A12 - A22, B21 + B22)

        C11 = M1 + M4 - M5 + M7
        C12 = M3 + M5
        C21 = M2 + M4
        C22 = M1 - M2 + M3 + M6

        C_top = np.hstack((C11, C12))
        C_bottom = np.hstack((C21, C22))
        C = np.vstack((C_top, C_bottom))
        
        return C

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

result = strassen(A, B)
print("Result of Strassen's Matrix Multiplication:")
print(result)
# Out:
# Result of Strassen's Matrix Multiplication:
# [[19 22]
#  [43 50]]

# %%
A = np.array([[1, 2], [3, 4]])
A_inv = np.linalg.inv(A)
print(np.dot(A, A_inv))
# Out:
# [[1.0000000e+00 0.0000000e+00]
#  [8.8817842e-16 1.0000000e+00]]

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 1000
steps = np.random.choice([-1, 1], size=(n, 2))
path = np.cumsum(steps, axis=0)
start = np.array([[0, 0]])
path = np.vstack([start, path])

plt.figure(figsize=(10, 6))
plt.plot(path[:, 0], path[:, 1], marker='o', markersize=3, linestyle='-')
plt.title('2D Random Walk')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
import numpy as np
from scipy.sparse import csr_matrix

dense_array = np.array([
    [0, 0, 0, 0],
    [5, 8, 0, 0],
    [0, 0, 3, 0],
    [0, 6, 0, 0]
])
sparse_matrix = csr_matrix(dense_array)
print("Sparse Matrix:\n", sparse_matrix)

vector = np.array([1, 2, 3, 4])
result = sparse_matrix.dot(vector)
print("Result of Matrix-Vector Multiplication:", result)
# Out:
# Sparse Matrix:
#  <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 4 stored elements and shape (4, 4)>
#   Coords	Values
#   (1, 0)	5
#   (1, 1)	8
#   (2, 2)	3
#   (3, 1)	6
# Result of Matrix-Vector Multiplication: [ 0 21  9 12]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve

def gaussian_kernel(size, sigma=1):
    size = int(size) // 2
    x, y = np.mgrid[-size:size+1, -size:size+1]
    normal = 1 / (2.0 * np.pi * sigma**2)
    g =  np.exp(-((x**2 + y**2) / (2.0*sigma**2))) * normal
    return g

image = np.random.rand(10,10)  # Simulated random image
kernel = gaussian_kernel(3, sigma=1)
blurred_image = convolve(image, kernel)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image')
plt.axis('off')

plt.show()

# %%
import numpy as np
A = np.array([[2, 1], [1, 2]])
eigenvalues, eigenvectors = np.linalg.eigh(A)
print(eigenvalues)
print(eigenvectors)
# Out:
# [1. 3.]
# [[-0.70710678  0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
import numpy as np
def func(x):
    return x ** 2
samples = np.random.uniform(0, 1, 10000)
estimate = np.mean(func(samples))
print(estimate)
# Out:
# 0.3322261932610721

# %%
import numpy as np
A = np.array([[12, -51, 4], [6, 167, -68], [-4, 24, -41]])
Q, R = np.linalg.qr(A)
b = np.array([1, 2, 3])
x = np.linalg.solve(R, Q.T @ b)
print(x)
# Out:
# [ 0.00938776 -0.02432653 -0.08832653]

# %%
import numpy as np
import matplotlib.pyplot as plt
signal = np.sin(2 * np.pi * np.arange(100) / 10)
fft = np.fft.fft(signal)
frequencies = np.fft.fftfreq(signal.size)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(signal)
plt.title('Original Signal')
plt.subplot(1, 2, 2)
plt.plot(frequencies, np.abs(fft))
plt.title('Frequency Spectrum')
plt.show()

# %%
import numpy as np
def fitness(x):
    return np.sum(x ** 2, axis=1)
population_size = 100
genes = 10
population = np.random.rand(population_size, genes)
for _ in range(100): 
    f = fitness(population)
    parents = population[np.argsort(f)[:population_size // 2]]
    children = parents.repeat(2, axis=0)  
    mutations = np.random.rand(population_size, genes) < 0.1  
    population = np.where(mutations, np.random.rand(population_size, genes), children)
best_individual = population[np.argmin(fitness(population))]
print(best_individual)
# Out:
# [0.09915026 0.14683148 0.0032819  0.13996253 0.04275776 0.17657022
#  0.05353218 0.06827594 0.14297216 0.04098876]

# %%
import numpy as np
import matplotlib.pyplot as plt

def initialize_centroids(data, k):
    indices = np.random.choice(data.shape[0], k, replace=False)
    return data[indices]

def assign_clusters(data, centroids):
    distances = np.linalg.norm(data[:, np.newaxis] - centroids, axis=2)
    return np.argmin(distances, axis=1)

def update_centroids(data, labels, k):
    new_centroids = np.array([data[labels == i].mean(axis=0) for i in range(k)])
    return new_centroids

def k_means(data, k, max_iters=100, tolerance=1e-4):
    centroids = initialize_centroids(data, k)
    for iteration in range(max_iters):
        old_centroids = np.copy(centroids)
        labels = assign_clusters(data, centroids)
        centroids = update_centroids(data, labels, k)
        if np.all(np.linalg.norm(centroids - old_centroids, axis=1) < tolerance):
            break
    return centroids, labels

np.random.seed(42)
data = np.random.rand(300, 2) * 100
k = 3
centroids, labels = k_means(data, k)

plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', edgecolor='k', label='Data Points')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='red', marker='o', label='Centroids')  # Changed marker to 'o'
plt.title('K-Means Clustering Results')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.linalg import expm
A = np.array([[0, 1], [-1, 0]])
exp_A = expm(A)
print(exp_A)
# Out:
# [[ 0.54030231  0.84147098]
#  [-0.84147098  0.54030231]]

# %%
from scipy.optimize import linprog
c = [-1, 4]
A = [[-3, 1], [1, 2]]
b = [6, 4]
result = linprog(c, A_ub=A, b_ub=b)
print(result)
# Out:
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -4.0
#               x: [ 4.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 4.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  6.000e+00]
#           upper:  residual: [       inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 1.800e+01  0.000e+00]
#                  marginals: [-0.000e+00 -1.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
